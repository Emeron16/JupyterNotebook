# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fortune 1000 companies in 2022 - 2022.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   rank in 2022                          1000 non-null   object
#  1   Name                                  1000 non-null   object
#  2   Revenue                               1000 non-null   object
#  3   revenue(% change)                     1000 non-null   object
#  4   profits in millions                   1000 non-null   object
#                      1000 non-null   object
#  6   assets                                1000 non-null   object
#  7   market value                          1000 non-null   object
#  8   change in rank of top 1000 companies  1000 non-null   object
#  9   employees                             1000 non-null   object
#  10  change in rank(500 only)
#             1000 non-null   object
# dtypes: object(11)
# ...

# %%
sorted_df = df.sort_values('market value', ascending = False)
sorted_df = sorted_df[sorted_df['market value'] != '-'].sort_values('market value').reset_index(drop = True)
sorted_df.head(20)
# Out:
#    rank in 2022                                 Name    Revenue  \
# 0           807  Calumet Specialty Products Partners     $3,148
# 1           839                       Avaya Holdings     $2,973
# 2           678                             Conduent     $4,140
# 3            65                                Tesla    $53,823
# 4           982                         Sleep Number  $2,184.90
# 5           919                              Griffon  $2,541.70
# 6           498                                 ARKO  $6,412.60
# 7           392                          SpartanNash     $8,931
# 8           688                  Bright Health Group  $4,029.40
# 9           722                            M/I Homes  $3,745.90
# 10          752                    Primoris Services  $3,497.60
# 11          700                            loanDepot  $3,943.20
# 12          885                  G-III Apparel Group  $2,766.50
# 13          911                                Guess  $2,591.60
# ...
