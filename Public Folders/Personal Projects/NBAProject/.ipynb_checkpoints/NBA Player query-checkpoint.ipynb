# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

file_Referee_202323 = 'Database/2022-2023_NBA_Referee_Stats.csv'
file_Player_202324 = 'Database/NBA_202324_NBA_Regular.csv'
file_Salary_202324 = 'Databse/NBA_Salary_202324.csv'
file_team_23 = 'Database/NBA_Salary_202324.csv'

# %%
def file_to_import(fileName,fileType = 'csv'):
    #Imports the specified table to be used
    if fileType == 'csv':
        df = pd.read_csv(fileName)
        
    elif fileType == 'xlsx':
        df = pd.read_excel(fileName)
    
    print(df.head())
    print(df.info())
    print("Row info:", df.index)
    return df

# %%
def plotGraph(graphType, df, xData,yData, xName = 'X', 
              yName = 'Y', titleName = 'Graph', figSizeX = 6.4, figSizeY = 4.8):

    #Checks to see if it is a special graph else plot using pandas DataFrame.
    if graphType == 'boxplot':
        sns.boxplot(x= xData, y= yData, data = df)
    elif graphType == 'lmplot':
        sns.lmplot(x= xData, y= yData, data = df)
    else:
        df.plot(x= xData, y= yData, kind = graphType)
    
    #Set labels
    plt.xlabel(xName)
    plt.ylabel(yName)
    plt.title(titleName)
    plt.show()
    plt.figure(figsize=(figSizeX, figSizeY))
    plt.clf()       

#Example to call: plotGraph('lmplot',df, "AGE", 'GP')

# %%
df = file_to_import(file_Player_202324)
# Out:
#    RANK                     NAME TEAM POS   AGE  GP   MPG  USG%   TO%  FTA  \
# 0   NaN              Joel Embiid  Phi   C  30.1  39  33.6  39.6  15.0  452
# 1   NaN              Luka Doncic  Dal   G  25.1  70  37.5  36.0  14.6  608
# 2   NaN    Giannis Antetokounmpo  Mil   F  29.4  73  35.2  33.0  15.4  782
# 3   NaN  Shai Gilgeous-Alexander  Okc   G  25.8  75  34.0  32.9   9.8  649
# 4   NaN            Jalen Brunson  Nyk   G  27.6  77  35.4  32.5  10.1  497
#
#    ...  APG  SPG  BPG  TPG   P+R   P+A  P+R+A    VI   ORtg   DRtg
# 0  ...  5.6  1.2  1.7  3.8  45.7  40.3   51.3  15.3  124.0  104.8
# 1  ...  9.8  1.4  0.5  4.0  43.1  43.7   52.9  15.5  121.9  109.9
# 2  ...  6.5  1.2  1.1  3.4  42.0  37.0   48.5  14.9  125.6  106.9
# 3  ...  6.2  2.0  0.9  2.2  35.6  36.3   41.8  11.9  128.6  107.7
# 4  ...  6.7  0.9  0.2  2.4  32.3  35.5   39.1  10.0  124.2  112.6
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RANK    0 non-null      float64
#  1   NAME    657 non-null    object
#  2   TEAM    657 non-null    object
#  3   POS     657 non-null    object
#  4   AGE     657 non-null    float64
#  5   GP      657 non-null    int64
#  6   MPG     657 non-null    float64
#  7   USG%    657 non-null    float64
#  8   TO%     657 non-null    float64
#  9   FTA     657 non-null    int64
#  10  FT%     657 non-null    float64
#  11  2PA     657 non-null    int64
#  12  2P%     657 non-null    float64
#  13  3PA     657 non-null    int64
#  14  3P%     657 non-null    float64
#  15  eFG%    657 non-null    float64
#  16  TS%     657 non-null    float64
#  17  PPG     657 non-null    float64
#  18  RPG     657 non-null    float64
#  19  APG     657 non-null    float64
#  20  SPG     657 non-null    float64
#  21  BPG     657 non-null    float64
#  22  TPG     657 non-null    float64
#  23  P+R     657 non-null    float64
#  24  P+A     657 non-null    float64
#  25  P+R+A   657 non-null    float64
#  26  VI      657 non-null    float64
#  27  ORtg    657 non-null    float64
#  28  DRtg    657 non-null    float64
# dtypes: float64(22), int64(4), object(3)
# memory usage: 149.0+ KB
# None
# Row info: RangeIndex(start=0, stop=657, step=1)

# %%
#Find the average age of top 10 players who average the most

PPG_sort = df[["NAME",'AGE','PPG','RPG', 'APG']].iloc[:10].sort_values('PPG', ascending = False)
print(PPG_sort)
ave_age = PPG_sort.AGE.mean()
print(f'Average Age for top 10 players: ', round(ave_age,2))
# Out:
#                       NAME   AGE   PPG   RPG  APG
# 0              Joel Embiid  30.1  34.7  11.0  5.6
# 1              Luka Doncic  25.1  33.9   9.2  9.8
# 2    Giannis Antetokounmpo  29.4  30.4  11.5  6.5
# 3  Shai Gilgeous-Alexander  25.8  30.1   5.5  6.2
# 4            Jalen Brunson  27.6  28.7   3.6  6.7
# 5             Kevin Durant  35.5  27.1   6.6  5.0
# 6             Devin Booker  27.5  27.1   4.5  6.9
# 7             Jayson Tatum  26.1  26.9   8.1  4.9
# 8             De'Aaron Fox  26.3  26.6   4.6  5.6
# 9         Donovan Mitchell  27.6  26.6   5.1  6.1
# Average Age for top 10 players:  28.1

# %%
#Get top ten players who played the most and then who averaged the most.

Most_Played = df[["NAME",'GP','PPG','RPG', 'APG']].sort_values('GP',ascending = False).iloc[:10]
Most_Played = Most_Played.sort_values('PPG', ascending = False)
print(Most_Played)
# Out:
#                          NAME  GP   PPG   RPG  APG
# 56                Jalen Green  82  19.6   5.2  3.5
# 55              Mikal Bridges  82  19.6   4.5  3.6
# 59           Domantas Sabonis  82  19.4  13.7  8.2
# 148           Harrison Barnes  82  12.2   3.0  1.2
# 189                Obi Toppin  82  10.3   3.9  1.6
# 190            Reggie Jackson  82  10.2   1.9  3.8
# 208          Payton Pritchard  82   9.6   3.2  3.4
# 211             Georges Niang  82   9.4   3.4  1.2
# 253  Nickeil Alexander-Walker  82   8.0   2.0  2.5
# 304             Cason Wallace  82   6.8   2.3  1.5
#     RANK                     NAME TEAM POS   AGE  GP   MPG  USG%   TO%  FTA  \
# 0    NaN              Joel Embiid  Phi   C  30.1  39  33.6  39.6  15.0  452
# 1    NaN              Luka Doncic  Dal   G  25.1  70  37.5  36.0  14.6  608
# 2    NaN    Giannis Antetokounmpo  Mil   F  29.4  73  35.2  33.0  15.4  782
# 3    NaN  Shai Gilgeous-Alexander  Okc   G  25.8  75  34.0  32.9   9.8  649
# 4    NaN            Jalen Brunson  Nyk   G  27.6  77  35.4  32.5  10.1  497
# 5    NaN             Kevin Durant  Pho   F  35.5  75  37.2  29.0  14.5  423
# 6    NaN             Devin Booker  Pho   G  27.5  68  36.0  29.8  12.0  457
# 7    NaN             Jayson Tatum  Bos   F  26.1  74  35.7  30.2  11.6  497
# 8    NaN             De'Aaron Fox  Sac   G  26.3  74  35.9  31.0  11.1  423
# 9    NaN         Donovan Mitchell  Cle   G  27.6  55  35.3  31.3  12.4  317
# 10   NaN            Stephen Curry  Gol   G  36.1  74  32.7  31.3  12.7  324
# 11   NaN             Nikola Jokic  Den   C  29.2  79  34.6  29.3  14.4  438
# 12   NaN          Anthony Edwards  Min   G  22.7  79  35.1  32.3  13.4  506
# 13   NaN             Tyrese Maxey  Phi   G  23.4  70  37.5  28.0   7.6  378
# 14   NaN             LeBron James  Lal   F  39.3  71  35.3  29.1  16.1  404
# 15   NaN               Trae Young  Atl   G  25.6  54  36.0  30.5  18.9  407
# 16   NaN             Kyrie Irving  Dal   G  32.1  58  35.0  28.1   8.6  210
# 17   NaN                Ja Morant  Mem   G  24.7   9  35.3  30.4  13.7   64
# 18   NaN            Anthony Davis  Lal   C  31.1  76  35.5  26.7  11.0  516
# 19   NaN           Damian Lillard  Mil   G  33.8  73  35.3  28.4  13.1  514
#
#     ...   APG  SPG  BPG  TPG   P+R   P+A  P+R+A    VI   ORtg   DRtg
# 0   ...   5.6  1.2  1.7  3.8  45.7  40.3   51.3  15.3  124.0  104.8
# 1   ...   9.8  1.4  0.5  4.0  43.1  43.7   52.9  15.5  121.9  109.9
# 2   ...   6.5  1.2  1.1  3.4  42.0  37.0   48.5  14.9  125.6  106.9
# 3   ...   6.2  2.0  0.9  2.2  35.6  36.3   41.8  11.9  128.6  107.7
# 4   ...   6.7  0.9  0.2  2.4  32.3  35.5   39.1  10.0  124.2  112.6
# 5   ...   5.0  0.9  1.2  3.3  33.7  32.1   38.7  10.4  117.8  112.8
# 6   ...   6.9  0.9  0.4  2.6  31.6  34.0   38.5  10.5  123.9  110.6
# 7   ...   4.9  1.0  0.6  2.5  35.0  31.8   39.9  11.5  120.6  107.6
# 8   ...   5.6  2.0  0.4  2.6  31.2  32.2   36.8   9.8  113.5  110.3
# 9   ...   6.1  1.8  0.5  2.8  31.7  32.7   37.7  10.6  116.9  109.1
# 10  ...   5.1  0.7  0.4  2.8  30.9  31.6   36.0  10.4  118.9  114.9
# 11  ...   9.0  1.4  0.9  3.0  38.8  35.4   47.7  16.6  130.7  104.8
# 12  ...   5.1  1.3  0.5  3.1  31.4  31.1   36.5  10.2  112.1  107.3
# 13  ...   6.2  1.0  0.5  1.7  29.6  32.1   35.8   9.0  120.9  113.9
# 14  ...   8.3  1.3  0.5  3.4  33.0  34.0   41.3  13.1  119.7  113.4
# 15  ...  10.8  1.3  0.2  4.4  28.5  36.5   39.3  10.2  117.4  118.3
# 16  ...   5.2  1.3  0.5  1.8  30.6  30.8   35.8  10.0  122.0  113.1
# 17  ...   8.1  0.8  0.6  3.0  30.7  33.2   38.8  11.8  116.1  112.9
# 18  ...   3.5  1.2  2.3  2.1  37.3  28.2   40.8  11.6  124.0  107.6
# 19  ...   7.0  1.0  0.2  2.6  28.7  31.3   35.7  10.3  120.0  114.3
#
# [20 rows x 29 columns]

# %%
#Find the amount of points a team scored all year
Sorted_Teams = df[['TEAM',"NAME",'PPG','RPG', 'APG']].sort_values('TEAM')
#Bostons Teams Players
Boston = Sorted_Teams[Sorted_Teams['TEAM'] == 'Bos'].sort_values('PPG', ascending = False)
#Bostons Points
Boston_Avg_Points = Boston.PPG.sum()
#Total points for each team
Teams_Total_points = Sorted_Teams.groupby('TEAM')['PPG'].agg('Sum')
print(Teams_Total_points)

print(Boston_Avg_Points)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 8
#       6 Boston_Avg_Points = Boston.PPG.sum()
#       7 #Total points for each team
# ----> 8 Teams_Total_points = Sorted_Teams.groupby('TEAM')['PPG'].agg('Sum')
#       9 print(Teams_Total_points)
#      11 print(Boston_Avg_Points)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:247, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     245     if engine_kwargs is not None:
#     246         kwargs["engine_kwargs"] = engine_kwargs
# --> 247     return getattr(self, func)(*args, **kwargs)
#     249 elif isinstance(func, abc.Iterable):
#     250     # Catch instances of lists / tuples
#     251     # but not the class list / tuple itself.
#     252     func = maybe_mangle_lambdas(func)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'Sum'
