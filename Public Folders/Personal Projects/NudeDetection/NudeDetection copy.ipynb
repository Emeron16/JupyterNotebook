# %%
from nudenet import NudeDetector
detector = NudeDetector()

# %%
male_path = '/Users/princemarcelle/Library/CloudStorage/OneDrive-Personal/Jupyter Notebook/Public Folders/Personal Projects/NudeDetection/nude men/'
women_path = '/Users/princemarcelle/Library/CloudStorage/OneDrive-Personal/Jupyter Notebook/Public Folders/Personal Projects/NudeDetection/nude women/'

# %%
detector.detect(women_path + 'nudewomen4.jpeg')
# Out:
# [{'class': 'FACE_FEMALE',
#   'score': 0.8385816812515259,
#   'box': [336, 132, 186, 220]},
#  {'class': 'BELLY_EXPOSED',
#   'score': 0.5144529342651367,
#   'box': [319, 412, 342, 311]},
#  {'class': 'FEMALE_GENITALIA_EXPOSED',
#   'score': 0.5141799449920654,
#   'box': [255, 670, 152, 283]},
#  {'class': 'FEMALE_BREAST_EXPOSED',
#   'score': 0.4895380437374115,
#   'box': [301, 315, 201, 183]},
#  {'class': 'FEMALE_BREAST_EXPOSED',
#   'score': 0.3731909394264221,
#   'box': [159, 375, 183, 203]}]

# %%
Image.open(women_path + 'nudewomen4.jpeg').to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=173x256>

# %%
#Image.open([male_path + 'nudemen1.jpeg', male_path + 'nudemen2.jpeg', male_path + 'nudemen3.jpeg', male_path + 'nudemen4.jpeg']).to_thumb(256,256)
detector.detect_batch([male_path + 'nudemen1.jpeg', male_path + 'nudemen2.jpeg', male_path + 'nudemen3.jpeg', male_path + 'nudemen4.jpeg'])
# Out:
# [[{'class': 'MALE_BREAST_EXPOSED',
#    'score': 0.6484052538871765,
#    'box': [977, 723, 252, 215]},
#   {'class': 'BELLY_EXPOSED',
#    'score': 0.6210968494415283,
#    'box': [929, 946, 371, 333]},
#   {'class': 'ARMPITS_EXPOSED',
#    'score': 0.6038971543312073,
#    'box': [1184, 731, 141, 132]}],
#  [{'class': 'FACE_FEMALE',
#    'score': 0.8131571412086487,
#    'box': [1308, 350, 287, 271]},
#   {'class': 'BELLY_EXPOSED',
#    'score': 0.7704144716262817,
#    'box': [811, 891, 439, 358]},
#   {'class': 'FEMALE_BREAST_EXPOSED',
#    'score': 0.7618314027786255,
#    'box': [1199, 737, 337, 288]},
#   {'class': 'FEMALE_BREAST_EXPOSED',
#    'score': 0.6825970411300659,
#    'box': [993, 638, 310, 278]},
#   {'class': 'ARMPITS_EXPOSED',
#    'score': 0.6725698709487915,
#    'box': [1456, 796, 155, 167]},
#   {'class': 'MALE_GENITALIA_EXPOSED',
#    'score': 0.6108430027961731,
#    'box': [516, 1155, 314, 283]},
#   {'class': 'FEET_EXPOSED',
# ...

# %%
detector = NudeDetector(model_path="640m.onnx", inference_resolution=640)

# %%
nude_detector.censor(male_path + 'nudemen1.jpeg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 nude_detector.censor(male_path + 'nudemen1.jpeg')
#
# NameError: name 'nude_detector' is not defined
